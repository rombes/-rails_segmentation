# %%
# Настройка Python 3.8 в Google Colab
# !bash ./Miniconda3-py38_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
# !conda install -q -y jupyter
# !conda install -q -y google-colab -c conda-forge
# !python -m ipykernel install --name "py38" --user
# Out:
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py38_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py38_0
#     - cffi==1.14.0=py38h2e261b9_0
#     - chardet==3.0.4=py38_1003
#     - conda-package-handling==1.6.0=py38h7b6447c_0
#     - conda==4.8.2=py38_0
#     - cryptography==2.8=py38h1ba5d50_0
#     - idna==2.8=py38_1000
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20181209=hc058e9b_0
#     - libffi==3.2.1=hd88cf55_4
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_0
#     - openssl==1.1.1d=h7b6447c_4
#     - pip==20.0.2=py38_1
#     - pycosat==0.6.3=py38h7b6447c_0
#     - pycparser==2.19=py_0
#     - pyopenssl==19.1.0=py38_0
#     - pysocks==1.7.1=py38_0
#     - python==3.8.1=h0371630_1
#     - readline==7.0=h7b6447c_5
#     - requests==2.22.0=py38_1
#     - ruamel_yaml==0.15.87=py38h7b6447c_0
#     - setuptools==45.2.0=py38_0
#     - six==1.14.0=py38_0
#     - sqlite==3.31.1=h7b6447c_0
#     - tk==8.6.8=hbc83047_0
#     - tqdm==4.42.1=py_0
#     - urllib3==1.25.8=py38_0
#     - wheel==0.34.2=py38_0
#     - xz==5.2.4=h14c3975_4
#     - yaml==0.1.7=had09818_2
#     - zlib==1.2.11=h7b6447c_3
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   asn1crypto         pkgs/main/linux-64::asn1crypto-1.3.0-py38_0
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2020.1.1-0
#   certifi            pkgs/main/linux-64::certifi-2019.11.28-py38_0
#   cffi               pkgs/main/linux-64::cffi-1.14.0-py38h2e261b9_0
#   chardet            pkgs/main/linux-64::chardet-3.0.4-py38_1003
#   conda              pkgs/main/linux-64::conda-4.8.2-py38_0
#   conda-package-han~ pkgs/main/linux-64::conda-package-handling-1.6.0-py38h7b6447c_0
#   cryptography       pkgs/main/linux-64::cryptography-2.8-py38h1ba5d50_0
#   idna               pkgs/main/linux-64::idna-2.8-py38_1000
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7
#   libedit            pkgs/main/linux-64::libedit-3.1.20181209-hc058e9b_0
#   libffi             pkgs/main/linux-64::libffi-3.2.1-hd88cf55_4
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-9.1.0-hdf63c60_0
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-9.1.0-hdf63c60_0
#   ncurses            pkgs/main/linux-64::ncurses-6.2-he6710b0_0
#   openssl            pkgs/main/linux-64::openssl-1.1.1d-h7b6447c_4
#   pip                pkgs/main/linux-64::pip-20.0.2-py38_1
#   pycosat            pkgs/main/linux-64::pycosat-0.6.3-py38h7b6447c_0
#   pycparser          pkgs/main/noarch::pycparser-2.19-py_0
#   pyopenssl          pkgs/main/linux-64::pyopenssl-19.1.0-py38_0
#   pysocks            pkgs/main/linux-64::pysocks-1.7.1-py38_0
#   python             pkgs/main/linux-64::python-3.8.1-h0371630_1
#   readline           pkgs/main/linux-64::readline-7.0-h7b6447c_5
#   requests           pkgs/main/linux-64::requests-2.22.0-py38_1
#   ruamel_yaml        pkgs/main/linux-64::ruamel_yaml-0.15.87-py38h7b6447c_0
#   setuptools         pkgs/main/linux-64::setuptools-45.2.0-py38_0
#   six                pkgs/main/linux-64::six-1.14.0-py38_0
#   sqlite             pkgs/main/linux-64::sqlite-3.31.1-h7b6447c_0
#   tk                 pkgs/main/linux-64::tk-8.6.8-hbc83047_0
#   tqdm               pkgs/main/noarch::tqdm-4.42.1-py_0
#   urllib3            pkgs/main/linux-64::urllib3-1.25.8-py38_0
#   wheel              pkgs/main/linux-64::wheel-0.34.2-py38_0
#   xz                 pkgs/main/linux-64::xz-5.2.4-h14c3975_4
#   yaml               pkgs/main/linux-64::yaml-0.1.7-had09818_2
#   zlib               pkgs/main/linux-64::zlib-1.2.11-h7b6447c_3
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - jupyter
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-5.1          |            1_gnu          21 KB
#     anyio-3.5.0                |   py38h06a4308_0         165 KB
#     argon2-cffi-21.3.0         |     pyhd3eb1b0_0          15 KB
#     argon2-cffi-bindings-21.2.0|   py38h7f8727e_0          33 KB
#     asttokens-2.0.5            |     pyhd3eb1b0_0          20 KB
#     attrs-22.1.0               |   py38h06a4308_0          85 KB
#     babel-2.11.0               |   py38h06a4308_0         6.8 MB
#     backcall-0.2.0             |     pyhd3eb1b0_0          13 KB
#     beautifulsoup4-4.12.2      |   py38h06a4308_0         209 KB
#     bleach-4.1.0               |     pyhd3eb1b0_0         123 KB
#     ca-certificates-2023.05.30 |       h06a4308_0         120 KB
#     certifi-2023.5.7           |   py38h06a4308_0         152 KB
#     comm-0.1.2                 |   py38h06a4308_0          13 KB
#     dbus-1.13.18               |       hb2f20db_0         504 KB
#     debugpy-1.5.1              |   py38h295c915_0         1.7 MB
#     decorator-5.1.1            |     pyhd3eb1b0_0          12 KB
#     defusedxml-0.7.1           |     pyhd3eb1b0_0          23 KB
#     entrypoints-0.4            |   py38h06a4308_0          16 KB
#     executing-0.8.3            |     pyhd3eb1b0_0          18 KB
#     expat-2.4.9                |       h6a678d5_0         156 KB
#     fontconfig-2.14.1          |       h52c9d5c_1         281 KB
#     freetype-2.12.1            |       h4a9f257_0         626 KB
#     giflib-5.2.1               |       h5eee18b_3          80 KB
#     glib-2.69.1                |       he621ea3_2         1.9 MB
#     gst-plugins-base-1.14.1    |       h6a678d5_1         2.2 MB
#     gstreamer-1.14.1           |       h5eee18b_1         1.7 MB
#     icu-58.2                   |       he6710b0_3        10.5 MB
#     importlib-metadata-6.0.0   |   py38h06a4308_0          38 KB
#     importlib_metadata-6.0.0   |       hd3eb1b0_0           8 KB
#     importlib_resources-5.2.0  |     pyhd3eb1b0_1          21 KB
#     ipykernel-6.19.2           |   py38hb070fc8_0         218 KB
#     ipython-8.12.0             |   py38h06a4308_0         1.1 MB
#     ipython_genutils-0.2.0     |     pyhd3eb1b0_1          27 KB
#     ipywidgets-8.0.4           |   py38h06a4308_0         194 KB
#     jedi-0.18.1                |   py38h06a4308_1         982 KB
#     jinja2-3.1.2               |   py38h06a4308_0         211 KB
#     jpeg-9e                    |       h5eee18b_1         262 KB
#     json5-0.9.6                |     pyhd3eb1b0_0          21 KB
#     jsonschema-4.17.3          |   py38h06a4308_0         140 KB
#     jupyter-1.0.0              |   py38h06a4308_8           7 KB
#     jupyter_client-8.1.0       |   py38h06a4308_0         178 KB
#     jupyter_console-6.6.3      |   py38h06a4308_0          45 KB
#     jupyter_core-5.3.0         |   py38h06a4308_0          89 KB
#     jupyter_server-1.13.5      |     pyhd3eb1b0_0         259 KB
#     jupyterlab-3.3.2           |     pyhd3eb1b0_0         3.6 MB
#     jupyterlab_pygments-0.1.2  |             py_0           8 KB
#     jupyterlab_server-2.10.3   |     pyhd3eb1b0_1          48 KB
#     jupyterlab_widgets-3.0.5   |   py38h06a4308_0         178 KB
#     krb5-1.20.1                |       h568e23c_1         1.3 MB
#     lerc-3.0                   |       h295c915_0         196 KB
#     libclang-10.0.1            |default_hb85057a_2        10.8 MB
#     libdeflate-1.17            |       h5eee18b_0          69 KB
#     libedit-3.1.20221030       |       h5eee18b_0         181 KB
#     libevent-2.1.12            |       h8f2d780_0         425 KB
#     libffi-3.4.4               |       h6a678d5_0         142 KB
#     libgcc-ng-11.2.0           |       h1234567_1         5.3 MB
#     libgomp-11.2.0             |       h1234567_1         474 KB
#     libllvm10-10.0.1           |       hbcb73fb_5        22.1 MB
#     libpng-1.6.39              |       h5eee18b_0         304 KB
#     libpq-12.15                |       h37d81fd_1         2.4 MB
#     libsodium-1.0.18           |       h7b6447c_0         244 KB
#     libstdcxx-ng-11.2.0        |       h1234567_1         4.7 MB
#     libtiff-4.5.0              |       h6a678d5_2         479 KB
#     libuuid-1.41.5             |       h5eee18b_0          27 KB
#     libwebp-1.2.4              |       h11a3e52_1          86 KB
#     libwebp-base-1.2.4         |       h5eee18b_1         376 KB
#     libxcb-1.15                |       h7f8727e_0         505 KB
#     libxkbcommon-1.0.1         |       hfa300c1_0         483 KB
#     libxml2-2.9.14             |       h74e7548_0         718 KB
#     libxslt-1.1.35             |       h4e12654_0         453 KB
#     lxml-4.9.1                 |   py38h1edc446_0         1.3 MB
#     lz4-c-1.9.4                |       h6a678d5_0         154 KB
#     markupsafe-2.1.1           |   py38h7f8727e_0          21 KB
#     matplotlib-inline-0.1.6    |   py38h06a4308_0          16 KB
#     mistune-0.8.4              |py38h7b6447c_1000          55 KB
#     nbclassic-0.5.5            |   py38h06a4308_0         6.1 MB
#     nbclient-0.5.13            |   py38h06a4308_0          91 KB
#     nbconvert-6.5.4            |   py38h06a4308_0         513 KB
#     nbformat-5.7.0             |   py38h06a4308_0         133 KB
#     ncurses-6.4                |       h6a678d5_0         914 KB
#     nest-asyncio-1.5.6         |   py38h06a4308_0          14 KB
#     notebook-6.5.4             |   py38h06a4308_0         540 KB
#     notebook-shim-0.2.2        |   py38h06a4308_0          22 KB
#     nspr-4.35                  |       h6a678d5_0         244 KB
#     nss-3.89.1                 |       h6a678d5_0         2.1 MB
#     openssl-1.1.1u             |       h7f8727e_0         3.7 MB
#     packaging-23.0             |   py38h06a4308_0          68 KB
#     pandocfilters-1.5.0        |     pyhd3eb1b0_0          11 KB
#     parso-0.8.3                |     pyhd3eb1b0_0          70 KB
#     pcre-8.45                  |       h295c915_0         207 KB
#     pexpect-4.8.0              |     pyhd3eb1b0_3          53 KB
#     pickleshare-0.7.5          |  pyhd3eb1b0_1003          13 KB
#     pkgutil-resolve-name-1.3.10|   py38h06a4308_0           9 KB
#     platformdirs-2.5.2         |   py38h06a4308_0          23 KB
#     ply-3.11                   |           py38_0          81 KB
#     prometheus_client-0.14.1   |   py38h06a4308_0          90 KB
#     prompt-toolkit-3.0.36      |   py38h06a4308_0         574 KB
#     prompt_toolkit-3.0.36      |       hd3eb1b0_0           5 KB
#     psutil-5.9.0               |   py38h5eee18b_0         330 KB
#     ptyprocess-0.7.0           |     pyhd3eb1b0_2          17 KB
#     pure_eval-0.2.2            |     pyhd3eb1b0_0          14 KB
#     pygments-2.15.1            |   py38h06a4308_1         1.8 MB
#     pyqt-5.15.7                |   py38h6a678d5_1         5.1 MB
#     pyqt5-sip-12.11.0          |   py38h6a678d5_1          87 KB
#     pyrsistent-0.18.0          |   py38heee7806_0          94 KB
#     python-3.8.17              |       h7a1cb2a_0        25.3 MB
#     python-dateutil-2.8.2      |     pyhd3eb1b0_0         233 KB
#     python-fastjsonschema-2.16.2|   py38h06a4308_0         230 KB
#     pytz-2022.7                |   py38h06a4308_0         209 KB
#     pyzmq-25.1.0               |   py38h6a678d5_0         461 KB
#     qt-main-5.15.2             |       h327a75a_7        45.1 MB
#     qt-webengine-5.15.9        |       hd2b0992_4        47.1 MB
#     qtconsole-5.4.2            |   py38h06a4308_0         191 KB
#     qtpy-2.2.0                 |   py38h06a4308_0          84 KB
#     qtwebkit-5.212             |       h4eab89a_4        14.3 MB
#     readline-8.2               |       h5eee18b_0         357 KB
#     send2trash-1.8.0           |     pyhd3eb1b0_1          19 KB
#     sip-6.6.2                  |   py38h6a678d5_0         425 KB
#     sniffio-1.2.0              |   py38h06a4308_1          15 KB
#     soupsieve-2.4              |   py38h06a4308_0          69 KB
#     sqlite-3.41.2              |       h5eee18b_0         1.2 MB
#     stack_data-0.2.0           |     pyhd3eb1b0_0          22 KB
#     terminado-0.17.1           |   py38h06a4308_0          31 KB
#     tinycss2-1.2.1             |   py38h06a4308_0          40 KB
#     tk-8.6.12                  |       h1ccaba5_0         3.0 MB
#     toml-0.10.2                |     pyhd3eb1b0_0          20 KB
#     tornado-6.2                |   py38h5eee18b_0         590 KB
#     traitlets-5.7.1            |   py38h06a4308_0         200 KB
#     typing-extensions-4.6.3    |   py38h06a4308_0           9 KB
#     typing_extensions-4.6.3    |   py38h06a4308_0          52 KB
#     wcwidth-0.2.5              |     pyhd3eb1b0_0          26 KB
#     webencodings-0.5.1         |           py38_1          20 KB
#     websocket-client-0.58.0    |   py38h06a4308_4          66 KB
#     widgetsnbextension-4.0.5   |   py38h06a4308_0         875 KB
#     xz-5.4.2                   |       h5eee18b_0         642 KB
#     zeromq-4.3.4               |       h2531618_0         331 KB
#     zipp-3.11.0                |   py38h06a4308_0          19 KB
#     zlib-1.2.13                |       h5eee18b_0         103 KB
#     zstd-1.5.5                 |       hc292b87_0         647 KB
#     ------------------------------------------------------------
#                                            Total:       252.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu
#   anyio              pkgs/main/linux-64::anyio-3.5.0-py38h06a4308_0
#   argon2-cffi        pkgs/main/noarch::argon2-cffi-21.3.0-pyhd3eb1b0_0
#   argon2-cffi-bindi~ pkgs/main/linux-64::argon2-cffi-bindings-21.2.0-py38h7f8727e_0
#   asttokens          pkgs/main/noarch::asttokens-2.0.5-pyhd3eb1b0_0
#   attrs              pkgs/main/linux-64::attrs-22.1.0-py38h06a4308_0
#   babel              pkgs/main/linux-64::babel-2.11.0-py38h06a4308_0
#   backcall           pkgs/main/noarch::backcall-0.2.0-pyhd3eb1b0_0
#   beautifulsoup4     pkgs/main/linux-64::beautifulsoup4-4.12.2-py38h06a4308_0
#   bleach             pkgs/main/noarch::bleach-4.1.0-pyhd3eb1b0_0
#   comm               pkgs/main/linux-64::comm-0.1.2-py38h06a4308_0
#   dbus               pkgs/main/linux-64::dbus-1.13.18-hb2f20db_0
#   debugpy            pkgs/main/linux-64::debugpy-1.5.1-py38h295c915_0
#   decorator          pkgs/main/noarch::decorator-5.1.1-pyhd3eb1b0_0
#   defusedxml         pkgs/main/noarch::defusedxml-0.7.1-pyhd3eb1b0_0
#   entrypoints        pkgs/main/linux-64::entrypoints-0.4-py38h06a4308_0
#   executing          pkgs/main/noarch::executing-0.8.3-pyhd3eb1b0_0
#   expat              pkgs/main/linux-64::expat-2.4.9-h6a678d5_0
#   fontconfig         pkgs/main/linux-64::fontconfig-2.14.1-h52c9d5c_1
#   freetype           pkgs/main/linux-64::freetype-2.12.1-h4a9f257_0
#   giflib             pkgs/main/linux-64::giflib-5.2.1-h5eee18b_3
#   glib               pkgs/main/linux-64::glib-2.69.1-he621ea3_2
#   gst-plugins-base   pkgs/main/linux-64::gst-plugins-base-1.14.1-h6a678d5_1
#   gstreamer          pkgs/main/linux-64::gstreamer-1.14.1-h5eee18b_1
#   icu                pkgs/main/linux-64::icu-58.2-he6710b0_3
#   importlib-metadata pkgs/main/linux-64::importlib-metadata-6.0.0-py38h06a4308_0
#   importlib_metadata pkgs/main/noarch::importlib_metadata-6.0.0-hd3eb1b0_0
#   importlib_resourc~ pkgs/main/noarch::importlib_resources-5.2.0-pyhd3eb1b0_1
#   ipykernel          pkgs/main/linux-64::ipykernel-6.19.2-py38hb070fc8_0
#   ipython            pkgs/main/linux-64::ipython-8.12.0-py38h06a4308_0
#   ipython_genutils   pkgs/main/noarch::ipython_genutils-0.2.0-pyhd3eb1b0_1
#   ipywidgets         pkgs/main/linux-64::ipywidgets-8.0.4-py38h06a4308_0
#   jedi               pkgs/main/linux-64::jedi-0.18.1-py38h06a4308_1
#   jinja2             pkgs/main/linux-64::jinja2-3.1.2-py38h06a4308_0
#   jpeg               pkgs/main/linux-64::jpeg-9e-h5eee18b_1
#   json5              pkgs/main/noarch::json5-0.9.6-pyhd3eb1b0_0
#   jsonschema         pkgs/main/linux-64::jsonschema-4.17.3-py38h06a4308_0
#   jupyter            pkgs/main/linux-64::jupyter-1.0.0-py38h06a4308_8
#   jupyter_client     pkgs/main/linux-64::jupyter_client-8.1.0-py38h06a4308_0
#   jupyter_console    pkgs/main/linux-64::jupyter_console-6.6.3-py38h06a4308_0
#   jupyter_core       pkgs/main/linux-64::jupyter_core-5.3.0-py38h06a4308_0
#   jupyter_server     pkgs/main/noarch::jupyter_server-1.13.5-pyhd3eb1b0_0
#   jupyterlab         pkgs/main/noarch::jupyterlab-3.3.2-pyhd3eb1b0_0
#   jupyterlab_pygmen~ pkgs/main/noarch::jupyterlab_pygments-0.1.2-py_0
#   jupyterlab_server  pkgs/main/noarch::jupyterlab_server-2.10.3-pyhd3eb1b0_1
#   jupyterlab_widgets pkgs/main/linux-64::jupyterlab_widgets-3.0.5-py38h06a4308_0
#   krb5               pkgs/main/linux-64::krb5-1.20.1-h568e23c_1
#   lerc               pkgs/main/linux-64::lerc-3.0-h295c915_0
#   libclang           pkgs/main/linux-64::libclang-10.0.1-default_hb85057a_2
#   libdeflate         pkgs/main/linux-64::libdeflate-1.17-h5eee18b_0
#   libevent           pkgs/main/linux-64::libevent-2.1.12-h8f2d780_0
#   libgomp            pkgs/main/linux-64::libgomp-11.2.0-h1234567_1
#   libllvm10          pkgs/main/linux-64::libllvm10-10.0.1-hbcb73fb_5
#   libpng             pkgs/main/linux-64::libpng-1.6.39-h5eee18b_0
#   libpq              pkgs/main/linux-64::libpq-12.15-h37d81fd_1
#   libsodium          pkgs/main/linux-64::libsodium-1.0.18-h7b6447c_0
#   libtiff            pkgs/main/linux-64::libtiff-4.5.0-h6a678d5_2
#   libuuid            pkgs/main/linux-64::libuuid-1.41.5-h5eee18b_0
#   libwebp            pkgs/main/linux-64::libwebp-1.2.4-h11a3e52_1
#   libwebp-base       pkgs/main/linux-64::libwebp-base-1.2.4-h5eee18b_1
#   libxcb             pkgs/main/linux-64::libxcb-1.15-h7f8727e_0
#   libxkbcommon       pkgs/main/linux-64::libxkbcommon-1.0.1-hfa300c1_0
#   libxml2            pkgs/main/linux-64::libxml2-2.9.14-h74e7548_0
#   libxslt            pkgs/main/linux-64::libxslt-1.1.35-h4e12654_0
#   lxml               pkgs/main/linux-64::lxml-4.9.1-py38h1edc446_0
#   lz4-c              pkgs/main/linux-64::lz4-c-1.9.4-h6a678d5_0
#   markupsafe         pkgs/main/linux-64::markupsafe-2.1.1-py38h7f8727e_0
#   matplotlib-inline  pkgs/main/linux-64::matplotlib-inline-0.1.6-py38h06a4308_0
#   mistune            pkgs/main/linux-64::mistune-0.8.4-py38h7b6447c_1000
#   nbclassic          pkgs/main/linux-64::nbclassic-0.5.5-py38h06a4308_0
#   nbclient           pkgs/main/linux-64::nbclient-0.5.13-py38h06a4308_0
#   nbconvert          pkgs/main/linux-64::nbconvert-6.5.4-py38h06a4308_0
#   nbformat           pkgs/main/linux-64::nbformat-5.7.0-py38h06a4308_0
#   nest-asyncio       pkgs/main/linux-64::nest-asyncio-1.5.6-py38h06a4308_0
#   notebook           pkgs/main/linux-64::notebook-6.5.4-py38h06a4308_0
#   notebook-shim      pkgs/main/linux-64::notebook-shim-0.2.2-py38h06a4308_0
#   nspr               pkgs/main/linux-64::nspr-4.35-h6a678d5_0
#   nss                pkgs/main/linux-64::nss-3.89.1-h6a678d5_0
#   packaging          pkgs/main/linux-64::packaging-23.0-py38h06a4308_0
#   pandocfilters      pkgs/main/noarch::pandocfilters-1.5.0-pyhd3eb1b0_0
#   parso              pkgs/main/noarch::parso-0.8.3-pyhd3eb1b0_0
#   pcre               pkgs/main/linux-64::pcre-8.45-h295c915_0
#   pexpect            pkgs/main/noarch::pexpect-4.8.0-pyhd3eb1b0_3
#   pickleshare        pkgs/main/noarch::pickleshare-0.7.5-pyhd3eb1b0_1003
#   pkgutil-resolve-n~ pkgs/main/linux-64::pkgutil-resolve-name-1.3.10-py38h06a4308_0
#   platformdirs       pkgs/main/linux-64::platformdirs-2.5.2-py38h06a4308_0
#   ply                pkgs/main/linux-64::ply-3.11-py38_0
#   prometheus_client  pkgs/main/linux-64::prometheus_client-0.14.1-py38h06a4308_0
#   prompt-toolkit     pkgs/main/linux-64::prompt-toolkit-3.0.36-py38h06a4308_0
#   prompt_toolkit     pkgs/main/noarch::prompt_toolkit-3.0.36-hd3eb1b0_0
#   psutil             pkgs/main/linux-64::psutil-5.9.0-py38h5eee18b_0
#   ptyprocess         pkgs/main/noarch::ptyprocess-0.7.0-pyhd3eb1b0_2
#   pure_eval          pkgs/main/noarch::pure_eval-0.2.2-pyhd3eb1b0_0
#   pygments           pkgs/main/linux-64::pygments-2.15.1-py38h06a4308_1
#   pyqt               pkgs/main/linux-64::pyqt-5.15.7-py38h6a678d5_1
#   pyqt5-sip          pkgs/main/linux-64::pyqt5-sip-12.11.0-py38h6a678d5_1
#   pyrsistent         pkgs/main/linux-64::pyrsistent-0.18.0-py38heee7806_0
#   python-dateutil    pkgs/main/noarch::python-dateutil-2.8.2-pyhd3eb1b0_0
#   python-fastjsonsc~ pkgs/main/linux-64::python-fastjsonschema-2.16.2-py38h06a4308_0
#   pytz               pkgs/main/linux-64::pytz-2022.7-py38h06a4308_0
#   pyzmq              pkgs/main/linux-64::pyzmq-25.1.0-py38h6a678d5_0
#   qt-main            pkgs/main/linux-64::qt-main-5.15.2-h327a75a_7
#   qt-webengine       pkgs/main/linux-64::qt-webengine-5.15.9-hd2b0992_4
#   qtconsole          pkgs/main/linux-64::qtconsole-5.4.2-py38h06a4308_0
#   qtpy               pkgs/main/linux-64::qtpy-2.2.0-py38h06a4308_0
#   qtwebkit           pkgs/main/linux-64::qtwebkit-5.212-h4eab89a_4
#   send2trash         pkgs/main/noarch::send2trash-1.8.0-pyhd3eb1b0_1
#   sip                pkgs/main/linux-64::sip-6.6.2-py38h6a678d5_0
#   sniffio            pkgs/main/linux-64::sniffio-1.2.0-py38h06a4308_1
#   soupsieve          pkgs/main/linux-64::soupsieve-2.4-py38h06a4308_0
#   stack_data         pkgs/main/noarch::stack_data-0.2.0-pyhd3eb1b0_0
#   terminado          pkgs/main/linux-64::terminado-0.17.1-py38h06a4308_0
#   tinycss2           pkgs/main/linux-64::tinycss2-1.2.1-py38h06a4308_0
#   toml               pkgs/main/noarch::toml-0.10.2-pyhd3eb1b0_0
#   tornado            pkgs/main/linux-64::tornado-6.2-py38h5eee18b_0
#   traitlets          pkgs/main/linux-64::traitlets-5.7.1-py38h06a4308_0
#   typing-extensions  pkgs/main/linux-64::typing-extensions-4.6.3-py38h06a4308_0
#   typing_extensions  pkgs/main/linux-64::typing_extensions-4.6.3-py38h06a4308_0
#   wcwidth            pkgs/main/noarch::wcwidth-0.2.5-pyhd3eb1b0_0
#   webencodings       pkgs/main/linux-64::webencodings-0.5.1-py38_1
#   websocket-client   pkgs/main/linux-64::websocket-client-0.58.0-py38h06a4308_4
#   widgetsnbextension pkgs/main/linux-64::widgetsnbextension-4.0.5-py38h06a4308_0
#   zeromq             pkgs/main/linux-64::zeromq-4.3.4-h2531618_0
#   zipp               pkgs/main/linux-64::zipp-3.11.0-py38h06a4308_0
#   zstd               pkgs/main/linux-64::zstd-1.5.5-hc292b87_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                                2020.1.1-0 --> 2023.05.30-h06a4308_0
#   certifi                                 2019.11.28-py38_0 --> 2023.5.7-py38h06a4308_0
#   libedit                           3.1.20181209-hc058e9b_0 --> 3.1.20221030-h5eee18b_0
#   libffi                                   3.2.1-hd88cf55_4 --> 3.4.4-h6a678d5_0
#   libgcc-ng                                9.1.0-hdf63c60_0 --> 11.2.0-h1234567_1
#   libstdcxx-ng                             9.1.0-hdf63c60_0 --> 11.2.0-h1234567_1
#   ncurses                                    6.2-he6710b0_0 --> 6.4-h6a678d5_0
#   openssl                                 1.1.1d-h7b6447c_4 --> 1.1.1u-h7f8727e_0
#   python                                   3.8.1-h0371630_1 --> 3.8.17-h7a1cb2a_0
#   readline                                   7.0-h7b6447c_5 --> 8.2-h5eee18b_0
#   sqlite                                  3.31.1-h7b6447c_0 --> 3.41.2-h5eee18b_0
#   tk                                       8.6.8-hbc83047_0 --> 8.6.12-h1ccaba5_0
#   xz                                       5.2.4-h14c3975_4 --> 5.4.2-h5eee18b_0
#   zlib                                    1.2.11-h7b6447c_3 --> 1.2.13-h5eee18b_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working...
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::libxcb==1.15=h7f8727e_0
#   - defaults/linux-64::jupyter==1.0.0=py38h06a4308_8
#   - defaults/linux-64::attrs==22.1.0=py38h06a4308_0
#   - defaults/linux-64::tk==8.6.12=h1ccaba5_0
#   - defaults/noarch::executing==0.8.3=pyhd3eb1b0_0
#   - defaults/linux-64::nbformat==5.7.0=py38h06a4308_0
#   - defaults/linux-64::tinycss2==1.2.1=py38h06a4308_0
#   - defaults/linux-64::libuuid==1.41.5=h5eee18b_0
#   - defaults/linux-64::ruamel_yaml==0.15.87=py38h7b6447c_0
#   - defaults/noarch::tqdm==4.42.1=py_0
#   - defaults/noarch::pycparser==2.19=py_0
#   - defaults/noarch::pexpect==4.8.0=pyhd3eb1b0_3
#   - defaults/noarch::stack_data==0.2.0=pyhd3eb1b0_0
#   - defaults/linux-64::sip==6.6.2=py38h6a678d5_0
#   - defaults/linux-64::libwebp-base==1.2.4=h5eee18b_1
#   - defaults/linux-64::markupsafe==2.1.1=py38h7f8727e_0
#   - defaults/linux-64::libxml2==2.9.14=h74e7548_0
#   - defaults/linux-64::lerc==3.0=h295c915_0
#   - defaults/linux-64::lz4-c==1.9.4=h6a678d5_0
#   - defaults/linux-64::webencodings==0.5.1=py38_1
#   - defaults/linux-64::idna==2.8=py38_1000
#   - defaults/linux-64::six==1.14.0=py38_0
#   - defaults/linux-64::qtconsole==5.4.2=py38h06a4308_0
#   - defaults/linux-64::expat==2.4.9=h6a678d5_0
#   - defaults/linux-64::dbus==1.13.18=hb2f20db_0
#   - defaults/linux-64::libsodium==1.0.18=h7b6447c_0
#   - defaults/linux-64::jupyter_core==5.3.0=py38h06a4308_0
#   - defaults/noarch::defusedxml==0.7.1=pyhd3eb1b0_0
#   - defaults/linux-64::entrypoints==0.4=py38h06a4308_0
#   - defaults/linux-64::prompt-toolkit==3.0.36=py38h06a4308_0
#   - defaults/linux-64::terminado==0.17.1=py38h06a4308_0
#   - defaults/noarch::prompt_toolkit==3.0.36=hd3eb1b0_0
#   - defaults/noarch::parso==0.8.3=pyhd3eb1b0_0
#   - defaults/noarch::send2trash==1.8.0=pyhd3eb1b0_1
#   - defaults/linux-64::soupsieve==2.4=py38h06a4308_0
#   - defaults/noarch::jupyterlab_pygments==0.1.2=py_0
#   - defaults/linux-64::conda-package-handling==1.6.0=py38h7b6447c_0
#   - defaults/linux-64::libtiff==4.5.0=h6a678d5_2
#   - defaults/linux-64::platformdirs==2.5.2=py38h06a4308_0
#   - defaults/linux-64::libffi==3.4.4=h6a678d5_0
#   - defaults/linux-64::typing-extensions==4.6.3=py38h06a4308_0
#   - defaults/linux-64::jedi==0.18.1=py38h06a4308_1
#   - defaults/linux-64::jsonschema==4.17.3=py38h06a4308_0
#   - defaults/linux-64::wheel==0.34.2=py38_0
#   - defaults/linux-64::pyqt==5.15.7=py38h6a678d5_1
#   - defaults/linux-64::libedit==3.1.20221030=h5eee18b_0
#   - defaults/noarch::decorator==5.1.1=pyhd3eb1b0_0
#   - defaults/linux-64::libclang==10.0.1=default_hb85057a_2
#   - defaults/linux-64::freetype==2.12.1=h4a9f257_0
#   - defaults/linux-64::nbconvert==6.5.4=py38h06a4308_0
#   - defaults/linux-64::libgcc-ng==11.2.0=h1234567_1
#   - defaults/linux-64::readline==8.2=h5eee18b_0
#   - defaults/linux-64::cffi==1.14.0=py38h2e261b9_0
#   - defaults/linux-64::jupyter_client==8.1.0=py38h06a4308_0
#   - defaults/linux-64::zlib==1.2.13=h5eee18b_0
#   - defaults/linux-64::pytz==2022.7=py38h06a4308_0
#   - defaults/linux-64::qtwebkit==5.212=h4eab89a_4
#   - defaults/noarch::importlib_metadata==6.0.0=hd3eb1b0_0
#   - defaults/noarch::backcall==0.2.0=pyhd3eb1b0_0
#   - defaults/linux-64::ipython==8.12.0=py38h06a4308_0
#   - defaults/linux-64::importlib-metadata==6.0.0=py38h06a4308_0
#   - defaults/linux-64::xz==5.4.2=h5eee18b_0
#   - defaults/linux-64::zeromq==4.3.4=h2531618_0
#   - defaults/linux-64::conda==4.8.2=py38_0
#   - defaults/noarch::asttokens==2.0.5=pyhd3eb1b0_0
#   - defaults/linux-64::libpq==12.15=h37d81fd_1
#   - defaults/linux-64::openssl==1.1.1u=h7f8727e_0
#   - defaults/linux-64::psutil==5.9.0=py38h5eee18b_0
#   - defaults/linux-64::pkgutil-resolve-name==1.3.10=py38h06a4308_0
#   - defaults/linux-64::anyio==3.5.0=py38h06a4308_0
#   - defaults/linux-64::setuptools==45.2.0=py38_0
#   - defaults/linux-64::sqlite==3.41.2=h5eee18b_0
#   - defaults/linux-64::pyopenssl==19.1.0=py38_0
#   - defaults/linux-64::zstd==1.5.5=hc292b87_0
#   - defaults/linux-64::ipykernel==6.19.2=py38hb070fc8_0
#   - defaults/linux-64::nspr==4.35=h6a678d5_0
#   - defaults/noarch::wcwidth==0.2.5=pyhd3eb1b0_0
#   - defaults/linux-64::libstdcxx-ng==11.2.0=h1234567_1
#   - defaults/linux-64::python==3.8.17=h7a1cb2a_0
#   - defaults/linux-64::urllib3==1.25.8=py38_0
#   - defaults/linux-64::zipp==3.11.0=py38h06a4308_0
#   - defaults/linux-64::qt-webengine==5.15.9=hd2b0992_4
#   - defaults/linux-64::krb5==1.20.1=h568e23c_1
#   - defaults/noarch::bleach==4.1.0=pyhd3eb1b0_0
#   - defaults/linux-64::qt-main==5.15.2=h327a75a_7
#   - defaults/linux-64::giflib==5.2.1=h5eee18b_3
#   - defaults/linux-64::debugpy==1.5.1=py38h295c915_0
#   - defaults/linux-64::babel==2.11.0=py38h06a4308_0
#   - defaults/linux-64::icu==58.2=he6710b0_3
#   - defaults/linux-64::argon2-cffi-bindings==21.2.0=py38h7f8727e_0
#   - defaults/linux-64::pyqt5-sip==12.11.0=py38h6a678d5_1
#   - defaults/linux-64::glib==2.69.1=he621ea3_2
#   - defaults/linux-64::gst-plugins-base==1.14.1=h6a678d5_1
#   - defaults/linux-64::ply==3.11=py38_0
#   - defaults/linux-64::pygments==2.15.1=py38h06a4308_1
#   - defaults/linux-64::fontconfig==2.14.1=h52c9d5c_1
#   - defaults/linux-64::ncurses==6.4=h6a678d5_0
#   - defaults/linux-64::pycosat==0.6.3=py38h7b6447c_0
#   - defaults/noarch::python-dateutil==2.8.2=pyhd3eb1b0_0
#   - defaults/linux-64::nest-asyncio==1.5.6=py38h06a4308_0
#   - defaults/noarch::importlib_resources==5.2.0=pyhd3eb1b0_1
#   - defaults/linux-64::lxml==4.9.1=py38h1edc446_0
#   - defaults/linux-64::libllvm10==10.0.1=hbcb73fb_5
#   - defaults/noarch::pandocfilters==1.5.0=pyhd3eb1b0_0
#   - defaults/linux-64::libdeflate==1.17=h5eee18b_0
#   - defaults/linux-64::nbclassic==0.5.5=py38h06a4308_0
#   - defaults/linux-64::gstreamer==1.14.1=h5eee18b_1
#   - defaults/linux-64::pyzmq==25.1.0=py38h6a678d5_0
#   - defaults/linux-64::widgetsnbextension==4.0.5=py38h06a4308_0
#   - defaults/noarch::pure_eval==0.2.2=pyhd3eb1b0_0
#   - defaults/linux-64::jinja2==3.1.2=py38h06a4308_0
#   - defaults/linux-64::traitlets==5.7.1=py38h06a4308_0
#   - defaults/noarch::ipython_genutils==0.2.0=pyhd3eb1b0_1
#   - defaults/linux-64::comm==0.1.2=py38h06a4308_0
#   - defaults/linux-64::qtpy==2.2.0=py38h06a4308_0
#   - defaults/linux-64::ipywidgets==8.0.4=py38h06a4308_0
#   - defaults/linux-64::matplotlib-inline==0.1.6=py38h06a4308_0
#   - defaults/linux-64::asn1crypto==1.3.0=py38_0
#   - defaults/linux-64::libevent==2.1.12=h8f2d780_0
#   - defaults/linux-64::typing_extensions==4.6.3=py38h06a4308_0
#   - defaults/noarch::jupyterlab==3.3.2=pyhd3eb1b0_0
#   - defaults/linux-64::libxkbcommon==1.0.1=hfa300c1_0
#   - defaults/noarch::toml==0.10.2=pyhd3eb1b0_0
#   - defaults/linux-64::jpeg==9e=h5eee18b_1
#   - defaults/noarch::json5==0.9.6=pyhd3eb1b0_0
#   - defaults/linux-64::mistune==0.8.4=py38h7b6447c_1000
#   - defaults/linux-64::pip==20.0.2=py38_1
#   - defaults/linux-64::sniffio==1.2.0=py38h06a4308_1
#   - defaults/linux-64::nss==3.89.1=h6a678d5_0
#   - defaults/linux-64::cryptography==2.8=py38h1ba5d50_0
#   - defaults/linux-64::libxslt==1.1.35=h4e12654_0
#   - defaults/noarch::pickleshare==0.7.5=pyhd3eb1b0_1003
#   - defaults/linux-64::libpng==1.6.39=h5eee18b_0
#   - defaults/linux-64::pcre==8.45=h295c915_0
#   - defaults/linux-64::requests==2.22.0=py38_1
#   - defaults/linux-64::chardet==3.0.4=py38_1003
#   - defaults/linux-64::notebook-shim==0.2.2=py38h06a4308_0
#   - defaults/linux-64::yaml==0.1.7=had09818_2
#   - defaults/linux-64::websocket-client==0.58.0=py38h06a4308_4
#   - defaults/linux-64::certifi==2023.5.7=py38h06a4308_0
#   - defaults/linux-64::pyrsistent==0.18.0=py38heee7806_0
#   - defaults/linux-64::tornado==6.2=py38h5eee18b_0
#   - defaults/linux-64::prometheus_client==0.14.1=py38h06a4308_0
#   - defaults/linux-64::python-fastjsonschema==2.16.2=py38h06a4308_0
#   - defaults/noarch::jupyter_server==1.13.5=pyhd3eb1b0_0
#   - defaults/linux-64::libwebp==1.2.4=h11a3e52_1
#   - defaults/linux-64::packaging==23.0=py38h06a4308_0
#   - defaults/noarch::ptyprocess==0.7.0=pyhd3eb1b0_2
#   - defaults/noarch::argon2-cffi==21.3.0=pyhd3eb1b0_0
#   - defaults/linux-64::pysocks==1.7.1=py38_0
#   - defaults/linux-64::notebook==6.5.4=py38h06a4308_0
#   - defaults/linux-64::beautifulsoup4==4.12.2=py38h06a4308_0
#   - defaults/linux-64::jupyter_console==6.6.3=py38h06a4308_0
#   - defaults/linux-64::nbclient==0.5.13=py38h06a4308_0
#   - defaults/noarch::jupyterlab_server==2.10.3=pyhd3eb1b0_1
#   - defaults/linux-64::jupyterlab_widgets==3.0.5=py38h06a4308_0
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - google-colab
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aiohttp-3.8.1              |   py38h0a891b7_1         574 KB  conda-forge
#     aiosignal-1.3.1            |     pyhd8ed1ab_0          12 KB  conda-forge
#     async-timeout-4.0.2        |     pyhd8ed1ab_0           9 KB  conda-forge
#     ca-certificates-2023.5.7   |       hbcca054_0         145 KB  conda-forge
#     cachetools-5.3.1           |     pyhd8ed1ab_0          14 KB  conda-forge
#     charset-normalizer-2.0.4   |     pyhd3eb1b0_0          35 KB
#     cryptography-3.4.8         |   py38h3e25421_1         1.1 MB  conda-forge
#     frozenlist-1.3.3           |   py38h5eee18b_0          45 KB
#     google-auth-2.22.0         |     pyh1a96a4e_0         100 KB  conda-forge
#     google-colab-1.0.0         |     pyh44b312d_0          77 KB  conda-forge
#     libblas-3.9.0              |15_linux64_openblas          12 KB  conda-forge
#     libcblas-3.9.0             |15_linux64_openblas          12 KB  conda-forge
#     libgfortran-ng-13.1.0      |       h69a702a_0          23 KB  conda-forge
#     libgfortran5-13.1.0        |       h15d22d2_0         1.4 MB  conda-forge
#     liblapack-3.9.0            |15_linux64_openblas          12 KB  conda-forge
#     libopenblas-0.3.20         |pthreads_h78a6416_0        10.1 MB  conda-forge
#     multidict-6.0.2            |   py38h5eee18b_0          49 KB
#     numpy-1.22.3               |   py38h99721a1_2         6.8 MB  conda-forge
#     pandas-1.3.5               |   py38h43a58ef_0        13.0 MB  conda-forge
#     portpicker-1.5.2           |     pyhd8ed1ab_0          17 KB  conda-forge
#     pyasn1-0.4.8               |             py_0          53 KB  conda-forge
#     pyasn1-modules-0.2.7       |             py_0          60 KB  conda-forge
#     pyopenssl-20.0.1           |     pyhd8ed1ab_0          48 KB  conda-forge
#     python_abi-3.8             |           2_cp38           4 KB  conda-forge
#     pyu2f-0.1.5                |     pyhd8ed1ab_0          31 KB  conda-forge
#     rsa-4.9                    |     pyhd8ed1ab_0          29 KB  conda-forge
#     yarl-1.7.2                 |   py38h0a891b7_2         133 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        33.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   aiohttp            conda-forge/linux-64::aiohttp-3.8.1-py38h0a891b7_1
#   aiosignal          conda-forge/noarch::aiosignal-1.3.1-pyhd8ed1ab_0
#   async-timeout      conda-forge/noarch::async-timeout-4.0.2-pyhd8ed1ab_0
#   cachetools         conda-forge/noarch::cachetools-5.3.1-pyhd8ed1ab_0
#   charset-normalizer pkgs/main/noarch::charset-normalizer-2.0.4-pyhd3eb1b0_0
#   frozenlist         pkgs/main/linux-64::frozenlist-1.3.3-py38h5eee18b_0
#   google-auth        conda-forge/noarch::google-auth-2.22.0-pyh1a96a4e_0
#   google-colab       conda-forge/noarch::google-colab-1.0.0-pyh44b312d_0
#   libblas            conda-forge/linux-64::libblas-3.9.0-15_linux64_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-15_linux64_openblas
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-13.1.0-h69a702a_0
#   libgfortran5       conda-forge/linux-64::libgfortran5-13.1.0-h15d22d2_0
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-15_linux64_openblas
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.20-pthreads_h78a6416_0
#   multidict          pkgs/main/linux-64::multidict-6.0.2-py38h5eee18b_0
#   numpy              conda-forge/linux-64::numpy-1.22.3-py38h99721a1_2
#   pandas             conda-forge/linux-64::pandas-1.3.5-py38h43a58ef_0
#   portpicker         conda-forge/noarch::portpicker-1.5.2-pyhd8ed1ab_0
#   pyasn1             conda-forge/noarch::pyasn1-0.4.8-py_0
#   pyasn1-modules     conda-forge/noarch::pyasn1-modules-0.2.7-py_0
#   python_abi         conda-forge/linux-64::python_abi-3.8-2_cp38
#   pyu2f              conda-forge/noarch::pyu2f-0.1.5-pyhd8ed1ab_0
#   rsa                conda-forge/noarch::rsa-4.9-pyhd8ed1ab_0
#   yarl               conda-forge/linux-64::yarl-1.7.2-py38h0a891b7_2
#
# The following packages will be UPDATED:
#
#   cryptography       pkgs/main::cryptography-2.8-py38h1ba5~ --> conda-forge::cryptography-3.4.8-py38h3e25421_1
#   pyopenssl          pkgs/main/linux-64::pyopenssl-19.1.0-~ --> conda-forge/noarch::pyopenssl-20.0.1-pyhd8ed1ab_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.05.30~ --> conda-forge::ca-certificates-2023.5.7-hbcca054_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installed kernelspec py38 in /root/.local/share/jupyter/kernels/py38

# %%
import sys
print(sys.version)
# Out:
# 3.8.17 (default, Jul  5 2023, 20:41:08)
# [GCC 11.2.0]

# %%
# !pip install -r ./requirements.txt
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/site-packages (from -r /content/drive/MyDrive/test_work/requirements.txt (line 1)) (1.22.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/site-packages (from -r /content/drive/MyDrive/test_work/requirements.txt (line 2)) (1.10.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.8/site-packages (from -r /content/drive/MyDrive/test_work/requirements.txt (line 3)) (10.0.0)
# Requirement already satisfied: cython in /usr/local/lib/python3.8/site-packages (from -r /content/drive/MyDrive/test_work/requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/site-packages (from -r /content/drive/MyDrive/test_work/requirements.txt (line 5)) (3.7.2)
# Requirement already satisfied: scikit-image==0.16.2 in /usr/local/lib/python3.8/site-packages (from -r /content/drive/MyDrive/test_work/requirements.txt (line 6)) (0.16.2)
# Requirement already satisfied: tensorflow==2.4.0 in /usr/local/lib/python3.8/site-packages (from -r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (2.4.0)
# Requirement already satisfied: keras==2.4.0 in /usr/local/lib/python3.8/site-packages (from -r /content/drive/MyDrive/test_work/requirements.txt (line 8)) (2.4.0)
# Requirement already satisfied: opencv-python==4.5.4.60 in /usr/local/lib/python3.8/site-packages (from -r /content/drive/MyDrive/test_work/requirements.txt (line 9)) (4.5.4.60)
# Requirement already satisfied: h5py==2.10.0 in /usr/local/lib/python3.8/site-packages (from -r /content/drive/MyDrive/test_work/requirements.txt (line 10)) (2.10.0)
# Requirement already satisfied: imgaug in /usr/local/lib/python3.8/site-packages (from -r /content/drive/MyDrive/test_work/requirements.txt (line 11)) (0.4.0)
# Requirement already satisfied: IPython[all] in /usr/local/lib/python3.8/site-packages (from -r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (8.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/site-packages (from matplotlib->-r /content/drive/MyDrive/test_work/requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/site-packages (from matplotlib->-r /content/drive/MyDrive/test_work/requirements.txt (line 5)) (4.41.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/site-packages (from matplotlib->-r /content/drive/MyDrive/test_work/requirements.txt (line 5)) (0.11.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.8/site-packages (from matplotlib->-r /content/drive/MyDrive/test_work/requirements.txt (line 5)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/site-packages (from matplotlib->-r /content/drive/MyDrive/test_work/requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/site-packages (from matplotlib->-r /content/drive/MyDrive/test_work/requirements.txt (line 5)) (23.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/site-packages (from matplotlib->-r /content/drive/MyDrive/test_work/requirements.txt (line 5)) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in /usr/local/lib/python3.8/site-packages (from matplotlib->-r /content/drive/MyDrive/test_work/requirements.txt (line 5)) (5.2.0)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.8/site-packages (from scikit-image==0.16.2->-r /content/drive/MyDrive/test_work/requirements.txt (line 6)) (3.1)
# Requirement already satisfied: PyWavelets>=0.4.0 in /usr/local/lib/python3.8/site-packages (from scikit-image==0.16.2->-r /content/drive/MyDrive/test_work/requirements.txt (line 6)) (1.4.1)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.8/site-packages (from scikit-image==0.16.2->-r /content/drive/MyDrive/test_work/requirements.txt (line 6)) (2.31.1)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.8/site-packages (from tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (3.3.0)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.8/site-packages (from tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (1.15.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.8/site-packages (from tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (1.6.3)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.8/site-packages (from tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (1.1.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.8/site-packages (from tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (3.7.4.3)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.8/site-packages (from tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (0.40.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.8/site-packages (from tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (1.12.1)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.8/site-packages (from tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.8/site-packages (from tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (0.3.3)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0rc0 in /usr/local/lib/python3.8/site-packages (from tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (2.4.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.8/site-packages (from tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (1.12)
# Requirement already satisfied: tensorboard~=2.4 in /usr/local/lib/python3.8/site-packages (from tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (2.13.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.8/site-packages (from tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (1.1.2)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.8/site-packages (from tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (0.15.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.8/site-packages (from tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (3.20.3)
# Requirement already satisfied: grpcio~=1.32.0 in /usr/local/lib/python3.8/site-packages (from tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (1.32.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/site-packages (from keras==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 8)) (6.0.1)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.8/site-packages (from imgaug->-r /content/drive/MyDrive/test_work/requirements.txt (line 11)) (2.0.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.8/site-packages (from IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.18.1)
# Requirement already satisfied: traitlets>=5 in /usr/local/lib/python3.8/site-packages (from IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (5.7.1)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /usr/local/lib/python3.8/site-packages (from IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (4.8.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/site-packages (from IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.2.0)
# Requirement already satisfied: stack-data in /usr/local/lib/python3.8/site-packages (from IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.2.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/site-packages (from IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.8/site-packages (from IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (2.15.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/site-packages (from IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /usr/local/lib/python3.8/site-packages (from IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (3.0.36)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.8/site-packages (from IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.1.6)
# Requirement already satisfied: ipykernel; extra == "all" in /usr/local/lib/python3.8/site-packages (from IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (6.19.2)
# Requirement already satisfied: nbconvert; extra == "all" in /usr/local/lib/python3.8/site-packages (from IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (6.5.4)
# Requirement already satisfied: pytest<7.1; extra == "all" in /usr/local/lib/python3.8/site-packages (from IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (6.2.5)
# Requirement already satisfied: pandas; extra == "all" in /usr/local/lib/python3.8/site-packages (from IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (1.3.5)
# Requirement already satisfied: black; extra == "all" in /usr/local/lib/python3.8/site-packages (from IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (23.7.0)
# Requirement already satisfied: curio; extra == "all" in /usr/local/lib/python3.8/site-packages (from IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (1.6)
# Requirement already satisfied: sphinx>=1.3; extra == "all" in /usr/local/lib/python3.8/site-packages (from IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (7.0.1)
# Requirement already satisfied: qtconsole; extra == "all" in /usr/local/lib/python3.8/site-packages (from IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (5.4.2)
# Requirement already satisfied: notebook; extra == "all" in /usr/local/lib/python3.8/site-packages (from IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (6.5.4)
# Requirement already satisfied: pytest-asyncio; extra == "all" in /usr/local/lib/python3.8/site-packages (from IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.21.1)
# Requirement already satisfied: ipywidgets; extra == "all" in /usr/local/lib/python3.8/site-packages (from IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (8.0.4)
# Requirement already satisfied: setuptools>=18.5; extra == "all" in /usr/local/lib/python3.8/site-packages (from IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (45.2.0.post20200210)
# Requirement already satisfied: ipyparallel; extra == "all" in /usr/local/lib/python3.8/site-packages (from IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (8.6.1)
# Requirement already satisfied: testpath; extra == "all" in /usr/local/lib/python3.8/site-packages (from IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.6.0)
# Requirement already satisfied: nbformat; extra == "all" in /usr/local/lib/python3.8/site-packages (from IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (5.7.0)
# Requirement already satisfied: sphinx-rtd-theme; extra == "all" in /usr/local/lib/python3.8/site-packages (from IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (1.2.2)
# Requirement already satisfied: docrepr; extra == "all" in /usr/local/lib/python3.8/site-packages (from IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.2.0)
# Requirement already satisfied: trio; extra == "all" in /usr/local/lib/python3.8/site-packages (from IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.22.2)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /usr/local/lib/python3.8/site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib->-r /content/drive/MyDrive/test_work/requirements.txt (line 5)) (3.11.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (2.22.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (0.7.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (2.22.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (1.0.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (2.3.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/site-packages (from jedi>=0.16->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/site-packages (from pexpect>4.3; sys_platform != "win32"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.7.0)
# Requirement already satisfied: executing in /usr/local/lib/python3.8/site-packages (from stack-data->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.8.3)
# Requirement already satisfied: asttokens in /usr/local/lib/python3.8/site-packages (from stack-data->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (2.0.5)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.8/site-packages (from stack-data->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.2.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.2.5)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.8/site-packages (from ipykernel; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (6.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.8/site-packages (from ipykernel; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (5.9.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.8/site-packages (from ipykernel; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (8.1.0)
# Requirement already satisfied: comm>=0.1.1 in /usr/local/lib/python3.8/site-packages (from ipykernel; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.1.2)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.8/site-packages (from ipykernel; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (25.1.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.8/site-packages (from ipykernel; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (1.5.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.8/site-packages (from ipykernel; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (1.5.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/site-packages (from nbconvert; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (2.1.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/site-packages (from nbconvert; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (4.9.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.8/site-packages (from nbconvert; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.1.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.8/site-packages (from nbconvert; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (4.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.8/site-packages (from nbconvert; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.8/site-packages (from nbconvert; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (1.2.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.8/site-packages (from nbconvert; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.8.4)
# Requirement already satisfied: jupyter-core>=4.7 in /usr/local/lib/python3.8/site-packages (from nbconvert; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (5.3.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.8/site-packages (from nbconvert; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.4)
# Requirement already satisfied: jinja2>=3.0 in /usr/local/lib/python3.8/site-packages (from nbconvert; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.8/site-packages (from nbconvert; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.5.13)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.8/site-packages (from nbconvert; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/site-packages (from nbconvert; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (4.12.2)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.8/site-packages (from pytest<7.1; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.8/site-packages (from pytest<7.1; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (1.2.0)
# Requirement already satisfied: py>=1.8.2 in /usr/local/lib/python3.8/site-packages (from pytest<7.1; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (1.11.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.8/site-packages (from pytest<7.1; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (22.1.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.8/site-packages (from pytest<7.1; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.10.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/site-packages (from pandas; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (2022.7)
# Requirement already satisfied: tomli>=1.1.0; python_version < "3.11" in /usr/local/lib/python3.8/site-packages (from black; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (2.0.1)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.8/site-packages (from black; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (2.5.2)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.8/site-packages (from black; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in /usr/local/lib/python3.8/site-packages (from black; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.11.1)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.8/site-packages (from black; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (8.1.6)
# Requirement already satisfied: importlib-metadata>=4.8; python_version < "3.10" in /usr/local/lib/python3.8/site-packages (from sphinx>=1.3; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (6.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /usr/local/lib/python3.8/site-packages (from sphinx>=1.3; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (1.1.5)
# Requirement already satisfied: babel>=2.9 in /usr/local/lib/python3.8/site-packages (from sphinx>=1.3; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (2.11.0)
# Requirement already satisfied: docutils<0.21,>=0.18.1 in /usr/local/lib/python3.8/site-packages (from sphinx>=1.3; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.20.1)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.8/site-packages (from sphinx>=1.3; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.7.13)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /usr/local/lib/python3.8/site-packages (from sphinx>=1.3; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (2.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.8/site-packages (from sphinx>=1.3; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (1.0.3)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.8/site-packages (from sphinx>=1.3; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (1.0.4)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.8/site-packages (from sphinx>=1.3; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (1.0.1)
# Requirement already satisfied: snowballstemmer>=2.0 in /usr/local/lib/python3.8/site-packages (from sphinx>=1.3; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (2.2.0)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.8/site-packages (from sphinx>=1.3; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (1.0.2)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.8/site-packages (from sphinx>=1.3; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (1.4.1)
# Requirement already satisfied: qtpy>=2.0.1 in /usr/local/lib/python3.8/site-packages (from qtconsole; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (2.2.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.8/site-packages (from qtconsole; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.2.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.8/site-packages (from notebook; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (1.8.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.8/site-packages (from notebook; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.8/site-packages (from notebook; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.5.5)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.8/site-packages (from notebook; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.8/site-packages (from notebook; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.17.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in /usr/local/lib/python3.8/site-packages (from ipywidgets; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /usr/local/lib/python3.8/site-packages (from ipywidgets; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (3.0.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/site-packages (from ipyparallel; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (4.42.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.8/site-packages (from nbformat; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (4.17.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.8/site-packages (from nbformat; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (2.16.2)
# Requirement already satisfied: sphinxcontrib-jquery<5,>=4 in /usr/local/lib/python3.8/site-packages (from sphinx-rtd-theme; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (4.1)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.8/site-packages (from trio; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (2.4.0)
# Requirement already satisfied: outcome in /usr/local/lib/python3.8/site-packages (from trio; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (1.2.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.8/site-packages (from trio; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9; python_version < "3.11" in /usr/local/lib/python3.8/site-packages (from trio; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (1.1.2)
# Requirement already satisfied: idna in /usr/local/lib/python3.8/site-packages (from trio; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (0.2.7)
# Requirement already satisfied: urllib3<2.0 in /usr/local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (1.25.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (4.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (2023.5.7)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (3.0.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard~=2.4->tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/site-packages (from bleach->nbconvert; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.5.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.8/site-packages (from beautifulsoup4->nbconvert; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (2.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in /usr/local/lib/python3.8/site-packages (from nbclassic>=0.4.7->notebook; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.8/site-packages (from nbclassic>=0.4.7->notebook; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (1.13.5)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.8/site-packages (from argon2-cffi->notebook; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (21.2.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10; python_version < "3.9" in /usr/local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (1.3.10)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.18.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard~=2.4->tensorflow==2.4.0->-r /content/drive/MyDrive/test_work/requirements.txt (line 7)) (3.2.2)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.8/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (0.58.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.8/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (3.5.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (1.14.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook; extra == "all"->IPython[all]->-r /content/drive/MyDrive/test_work/requirements.txt (line 12)) (2.19)

# %%
# !pip install seaborn
# !pip install scikit-learn
# !pip install protobuf==3.20.*
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      |████████████████████████████████| 293 kB 6.5 MB/s
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.8/site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.8/site-packages (from seaborn) (1.3.5)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /usr/local/lib/python3.8/site-packages (from seaborn) (1.22.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in /usr/local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (5.2.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.41.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.1.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.15.0)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /usr/local/lib/python3.8/site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib!=3.6.1,>=3.1->seaborn) (3.11.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2

# %%
import os
import sys
import json
import datetime
import numpy as np
import skimage.draw
import cv2
from mrcnn.visualize import display_instances
import matplotlib.pyplot as plt
import imgaug
# Out:
# 2023-07-20 14:09:57.193086: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0

# %%
# Корневой каталог проекта
ROOT_DIR = "/content/drive/MyDrive/test_work"

# Импорт Mask RCNN
sys.path.append(ROOT_DIR)  # путь до локальной версии библиотеки
from mrcnn.config import Config
from mrcnn import model as modellib, utils

# Путь к файлу тренировочных весов
COCO_WEIGHTS_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")

# Каталог для сохранения журналов и контрольных точек модели, если он не указан
# через аргумент командной строки --logs
DEFAULT_LOGS_DIR = os.path.join(ROOT_DIR, "logs")

# %%
class CustomConfig(Config):
    """
    Конфигурация для обучения на пользовательском наборе данных.
    Унаследован от базового класса Config и переопределяет некоторые значения.
    """
    # Дайте конфигурации узнаваемое имя
    NAME = "object"


    # КОЛИЧЕСТВО графических процессоров для использования. При использовании только ЦП необходимо установить значение 1.
    GPU_COUNT = 1

    # Мы используем графический процессор с 12 ГБ памяти, который может вместить два изображения.
    # Уменьшите значение, если вы используете меньший графический процессор.

    IMAGES_PER_GPU = 1

    # Количество классов вклюяая фон
    NUM_CLASSES = 1 + 1  # Фон + Рельсы

    # Количество шагов обучения в эпоху

    STEPS_PER_EPOCH = 5

    # Пропустить обнаружения с < 90% точностью
    DETECTION_MIN_CONFIDENCE = 0.9

    LEARNING_RATE = 0.001

# %%
############################################################
#  Dataset
############################################################

class CustomDataset(utils.Dataset):

    def load_custom(self, dataset_dir, subset, jsons, ns):
        """ 
        dataset_dir: корневой каталог набора данных.
        subset: Подмножество для загрузки: train или val
        jsons: путь до JSON-файла с разметкой
        ns: Наименование меток в JSON
        """
        
        # Добавление классов
        self.add_class("object", 1, "Rails")


        dataset_dir = os.path.join(dataset_dir, subset)

        # Загрзука аннотации
        # VGG Image Annotator сохраняет каждое изображение в виде:
        # { 'filename': '28503151_5b5b7ec140_b.jpg',
        #   'regions': {
        #       '0': {
        #           'region_attributes': {},
        #           'shape_attributes': {
        #               'all_points_x': [...],
        #               'all_points_y': [...],
        #               'name': 'polygon'}},
        #       ... more regions ...
        #   },
        #   'size': 100202
        # }
        # В основном нас интересуют координаты x и y каждой области
        annotations1 = json.load(open(jsons))
        annotations = list(annotations1.values())  # ключи не нужны

        # The VIA tool сохраняет изображения в JSON, даже если они не имеют аннотаций 
        # Пропустить неаннотированные изображения.
        annotations = [a for a in annotations if a['regions']]

        # Добавиляем изображение
        for a in annotations:
            # Получаем координаты x, y точек многоугольников, составляющих
            # схема каждого экземпляра объекта. В
            # shape_attributes есть хранилища (смотрите формат json выше)
            polygons = [r['shape_attributes'] for r in a['regions']]
            objects = [s['region_attributes'][ns] for s in a['regions']]
            print("objects:",objects)
            name_dict = {"Rails": 1}

            num_ids = [name_dict[a] for a in objects]

            # load_mask() нужен размер изображения, чтобы преобразовать полигоны в маски.
            # К сожалению, VIA не включает его в JSON, поэтому мы должны прочитать
            print("numids",num_ids)
            image_path = os.path.join(dataset_dir, a['filename'])
            image = skimage.io.imread(image_path)
            height, width = image.shape[:2]

            self.add_image(
                "object",  # для одного класса просто добавьте название здесь
                image_id=a['filename'],  # используйте имя файла в качестве уникального идентификатора изображения
                path=image_path,
                width=width, height=height,
                polygons=polygons,
                num_ids=num_ids
                )

    def load_mask(self, image_id):
        """Создание масок экземпляра для изображения.
       Returns:
        masks: Массив bool формы [height, width, instance count] с одной маской на экземпляр.
        class_ids: одномерный массив идентификаторов классов масок экземпляра.
        """
        
        image_info = self.image_info[image_id]
        if image_info["source"] != "object":
            return super(self.__class__, self).load_mask(image_id)

        # Преобразуйте полигоны в растровую маску формы
        # [height, width, instance_count]
        info = self.image_info[image_id]
        if info["source"] != "object":
            return super(self.__class__, self).load_mask(image_id)
        num_ids = info['num_ids']
        mask = np.zeros([info["height"], info["width"], len(info["polygons"])],
                        dtype=np.uint8)
        for i, p in enumerate(info["polygons"]):
            # Получите индексы пикселей внутри многоугольника и установите их равными 1
        	rr, cc = skimage.draw.polygon(p['all_points_y'], p['all_points_x'])

        	mask[rr, cc, i] = 1

        # Возвращает маску и массив идентификаторов классов каждого экземпляра. С тех пор как у нас есть
        # только один идентификатор класса, мы возвращаем массив из 1s
        # Сопоставьте имена классов с идентификаторами классов.
        num_ids = np.array(num_ids, dtype=np.int32)
        return mask, num_ids #np.ones([mask.shape[-1]], dtype=np.int32)

    def image_reference(self, image_id):
        """Возвращаем путь к изображению."""
        info = self.image_info[image_id]
        if info["source"] == "object":
            return info["path"]
        else:
            super(self.__class__, self).image_reference(image_id)

# %%
def train(model):
    """Обучение модели."""
    # Обучающий набор данных.
    dataset_train = CustomDataset()
    dataset_train.load_custom("/content/drive/MyDrive/test_work/datasets/", "train", '/content/drive/MyDrive/test_work/datasets/train/train.json', 'Rails')
    dataset_train.prepare()

    # Проверочный набор данных
    dataset_val = CustomDataset()
    dataset_val.load_custom("/content/drive/MyDrive/test_work/datasets/", "val", '/content/drive/MyDrive/test_work/datasets/val/val.json', 'names')
    dataset_val.prepare()

    model.train(dataset_train, dataset_val,
                learning_rate=config.LEARNING_RATE,
                epochs=250,
                layers='heads')

    # Аугментация изображений
    # model.train(dataset_train, dataset_val,
    #             learning_rate=config.LEARNING_RATE,
    #             epochs=300,
    #             layers='heads', #layers='all',
    #             augmentation = imgaug.augmenters.Sequential([
    #             imgaug.augmenters.Fliplr(1),
    #             imgaug.augmenters.Flipud(1),
    #             imgaug.augmenters.Affine(rotate=(-45, 45)),
    #             imgaug.augmenters.Affine(rotate=(-90, 90)),
    #             imgaug.augmenters.Affine(scale=(0.5, 1.5)),
    #             imgaug.augmenters.Crop(px=(0, 10)),
    #             imgaug.augmenters.Grayscale(alpha=(0.0, 1.0)),
    #             imgaug.augmenters.AddToHueAndSaturation((-20, 20)), # change hue and saturation
    #             imgaug.augmenters.Add((-10, 10), per_channel=0.5), # change brightness of images (by -10 to 10 of original value)
    #             imgaug.augmenters.Invert(0.05, per_channel=True), # invert color channels
    #             imgaug.augmenters.Sharpen(alpha=(0, 1.0), lightness=(0.75, 1.5)), # sharpen images

    #             ]

    #             ))

# Другой способ аугментации
# augmentation = imgaug.Sometimes(5/6,aug.OneOf(
                                            # [
                                            # imgaug.augmenters.Fliplr(1),
                                            # imgaug.augmenters.Flipud(1),
                                            # imgaug.augmenters.Affine(rotate=(-45, 45)),
                                            # imgaug.augmenters.Affine(rotate=(-90, 90)),
                                            # imgaug.augmenters.Affine(scale=(0.5, 1.5))
                                             # ]
                                        # )
                                   # )
# Out:
# '\n this augmentation is applied consecutively to each image. In other words, for each image, the augmentation apply flip LR,\n and then followed by flip UD, then followed by rotation of -45 and 45, then followed by another rotation of -90 and 90,\n and lastly followed by scaling with factor 0.5 and 1.5. '

# %%
config = CustomConfig()
model = modellib.MaskRCNN(mode="training", config=config,
                                  model_dir=DEFAULT_LOGS_DIR)

weights_path = COCO_WEIGHTS_PATH
        # Загрузка файла с весами
if not os.path.exists(weights_path):
  utils.download_trained_weights(weights_path)

model.load_weights(weights_path, by_name=True, exclude=[
            "mrcnn_class_logits", "mrcnn_bbox_fc",
            "mrcnn_bbox", "mrcnn_mask"])

train(model)
# Out:
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/2534ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/2542ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/2546ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/2551ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/2558ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/2562ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/2568ia.jpg
# objects: ['Rails']
# numids [1]
# /content/drive/MyDrive/test_work/datasets/train/2574ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/2578ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/2585ia.jpg
# objects: ['Rails']
# numids [1]
# /content/drive/MyDrive/test_work/datasets/train/2590ia.jpg
# objects: ['Rails']
# numids [1]
# /content/drive/MyDrive/test_work/datasets/train/2594ia.jpg
# objects: ['Rails']
# numids [1]
# /content/drive/MyDrive/test_work/datasets/train/2602ia.jpg
# objects: ['Rails']
# numids [1]
# /content/drive/MyDrive/test_work/datasets/train/2606ia.jpg
# objects: ['Rails']
# numids [1]
# /content/drive/MyDrive/test_work/datasets/train/2611ia.jpg
# objects: ['Rails']
# numids [1]
# /content/drive/MyDrive/test_work/datasets/train/2618ia.jpg
# objects: ['Rails']
# numids [1]
# /content/drive/MyDrive/test_work/datasets/train/2622ia.jpg
# objects: ['Rails', 'Rails']
# numids [1, 1]
# /content/drive/MyDrive/test_work/datasets/train/2628ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/2634ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/2638ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/2645ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/2650ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/2654ia.jpg
# objects: ['Rails', 'Rails', 'Rails', 'Rails']
# numids [1, 1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/2662ia.jpg
# objects: ['Rails', 'Rails', 'Rails', 'Rails']
# numids [1, 1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/2666ia.jpg
# objects: ['Rails', 'Rails', 'Rails', 'Rails']
# numids [1, 1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/2671ia.jpg
# objects: ['Rails', 'Rails', 'Rails', 'Rails']
# numids [1, 1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/2678ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/2682ia.jpg
# objects: ['Rails', 'Rails', 'Rails', 'Rails']
# numids [1, 1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/2688ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/2693ia.jpg
# objects: ['Rails', 'Rails', 'Rails', 'Rails']
# numids [1, 1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/2697ia.jpg
# objects: ['Rails', 'Rails', 'Rails', 'Rails']
# numids [1, 1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/2703ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/3042ia.jpg
# objects: ['Rails']
# numids [1]
# /content/drive/MyDrive/test_work/datasets/train/3048ia.jpg
# objects: ['Rails', 'Rails']
# numids [1, 1]
# /content/drive/MyDrive/test_work/datasets/train/3053ia.jpg
# objects: ['Rails', 'Rails']
# numids [1, 1]
# /content/drive/MyDrive/test_work/datasets/train/3057ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/3063ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/3068ia.jpg
# objects: ['Rails']
# numids [1]
# /content/drive/MyDrive/test_work/datasets/train/3072ia.jpg
# objects: ['Rails']
# numids [1]
# /content/drive/MyDrive/test_work/datasets/train/3078ia.jpg
# objects: ['Rails']
# numids [1]
# /content/drive/MyDrive/test_work/datasets/train/3083ia.jpg
# objects: ['Rails']
# numids [1]
# /content/drive/MyDrive/test_work/datasets/train/3087ia.jpg
# objects: ['Rails', 'Rails']
# numids [1, 1]
# /content/drive/MyDrive/test_work/datasets/train/3093ia.jpg
# objects: ['Rails', 'Rails']
# numids [1, 1]
# /content/drive/MyDrive/test_work/datasets/train/3098ia.jpg
# objects: ['Rails', 'Rails']
# numids [1, 1]
# /content/drive/MyDrive/test_work/datasets/train/3102ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/3108ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/3113ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/3117ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/3123ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/3128ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/3132ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/3138ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/3143ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/3147ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/3153ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/3158ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/3162ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/3168ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_13_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_15_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_17_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_31_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_36_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_38_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_40_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_51_sec.jpg
# objects: ['Rails', 'Rails', 'Rails', 'Rails']
# numids [1, 1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_110_sec.jpg
# objects: ['Rails', 'Rails']
# numids [1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_112_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_119_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_125_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_147_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_152_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_183_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_189_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_195_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_216_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_220_sec.jpg
# objects: ['Rails', 'Rails', 'Rails', 'Rails']
# numids [1, 1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_224_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_242_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_250_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_254_sec.jpg
# objects: ['Rails', 'Rails']
# numids [1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_276_sec.jpg
# objects: ['Rails', 'Rails', 'Rails', 'Rails', 'Rails']
# numids [1, 1, 1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_312_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_450_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_456_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_462_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_469_sec.jpg
# objects: ['Rails', 'Rails']
# numids [1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_484_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_503_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_511_sec.jpg
# objects: ['Rails', 'Rails']
# numids [1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_515_sec.jpg
# objects: ['Rails', 'Rails', 'Rails', 'Rails']
# numids [1, 1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_1020_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_1028_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_1033_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_1038_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_1047_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_1054_sec.jpg
# objects: ['Rails', 'Rails']
# numids [1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_1058_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_1063_sec.jpg
# objects: ['Rails', 'Rails']
# numids [1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_1071_sec.jpg
# objects: ['Rails', 'Rails']
# numids [1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_1077_sec.jpg
# objects: ['Rails', 'Rails']
# numids [1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_1080_sec.jpg
# objects: ['Rails', 'Rails']
# numids [1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_1087_sec.jpg
# objects: ['Rails', 'Rails']
# numids [1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_1093_sec.jpg
# objects: ['Rails', 'Rails']
# numids [1, 1]
# /content/drive/MyDrive/test_work/datasets/train/img_kjtv_1098_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/val/2545ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/val/2563ia.jpg
# objects: ['Rails', 'Rails']
# numids [1, 1]
# /content/drive/MyDrive/test_work/datasets/val/2581ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/val/2608ia.jpg
# objects: ['Rails']
# numids [1]
# /content/drive/MyDrive/test_work/datasets/val/2626ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/val/2647ia.jpg
# objects: ['Rails', 'Rails']
# numids [1, 1]
# /content/drive/MyDrive/test_work/datasets/val/2664ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/val/2707ia.jpg
# objects: ['Rails']
# numids [1]
# /content/drive/MyDrive/test_work/datasets/val/2724ia.jpg
# objects: ['Rails']
# numids [1]
# /content/drive/MyDrive/test_work/datasets/val/2740ia.jpg
# objects: ['Rails']
# numids [1]
# /content/drive/MyDrive/test_work/datasets/val/2756ia.jpg
# objects: ['Rails']
# numids [1]
# /content/drive/MyDrive/test_work/datasets/val/2773ia.jpg
# objects: ['Rails', 'Rails']
# numids [1, 1]
# /content/drive/MyDrive/test_work/datasets/val/2806ia.jpg
# objects: ['Rails', 'Rails']
# numids [1, 1]
# /content/drive/MyDrive/test_work/datasets/val/2825ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/val/2841ia.jpg
# objects: ['Rails', 'Rails']
# numids [1, 1]
# /content/drive/MyDrive/test_work/datasets/val/2857ia.jpg
# objects: ['Rails', 'Rails']
# numids [1, 1]
# /content/drive/MyDrive/test_work/datasets/val/2874ia.jpg
# objects: ['Rails']
# numids [1]
# /content/drive/MyDrive/test_work/datasets/val/2906ia.jpg
# objects: ['Rails']
# numids [1]
# /content/drive/MyDrive/test_work/datasets/val/2923ia.jpg
# objects: ['Rails']
# numids [1]
# /content/drive/MyDrive/test_work/datasets/val/2939ia.jpg
# objects: ['Rails']
# numids [1]
# /content/drive/MyDrive/test_work/datasets/val/3007ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/val/3024ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/val/3040ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/val/3056ia.jpg
# objects: ['Rails']
# numids [1]
# /content/drive/MyDrive/test_work/datasets/val/3073ia.jpg
# objects: ['Rails']
# numids [1]
# /content/drive/MyDrive/test_work/datasets/val/3089ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/val/3106ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/val/3125ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/val/3141ia.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/val/3157ia.jpg
# objects: ['Rails', 'Rails']
# numids [1, 1]
# /content/drive/MyDrive/test_work/datasets/val/img_kjtv_16_sec.jpg
# objects: ['Rails', 'Rails']
# numids [1, 1]
# /content/drive/MyDrive/test_work/datasets/val/img_kjtv_19_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/val/img_kjtv_113_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/val/img_kjtv_145_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/val/img_kjtv_228_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/val/img_kjtv_274_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/val/img_kjtv_325_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/val/img_kjtv_354_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/val/img_kjtv_389_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/val/img_kjtv_416_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/val/img_kjtv_452_sec.jpg
# objects: ['Rails', 'Rails']
# numids [1, 1]
# /content/drive/MyDrive/test_work/datasets/val/img_kjtv_483_sec.jpg
# objects: ['Rails', 'Rails']
# numids [1, 1]
# /content/drive/MyDrive/test_work/datasets/val/img_kjtv_516_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/val/img_kjtv_1022_sec.jpg
# objects: ['Rails', 'Rails', 'Rails']
# numids [1, 1, 1]
# /content/drive/MyDrive/test_work/datasets/val/img_kjtv_1040_sec.jpg
#
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: /content/drive/MyDrive/test_work/logs/object20230720T1419/mask_rcnn_object_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# rpn_model              (Functional)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 1/250
# /usr/local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:435: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training_2/SGD/gradients/gradients/roi_align_classifier_1/concat_grad/sub:0", shape=(None,), dtype=int32), values=Tensor("training_2/SGD/gradients/gradients/roi_align_classifier_1/concat_grad/GatherV2_2:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("training_2/SGD/gradients/gradients/roi_align_classifier_1/concat_grad/Shape:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:435: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training_2/SGD/gradients/gradients/roi_align_classifier_1/concat_grad/sub_1:0", shape=(None,), dtype=int32), values=Tensor("training_2/SGD/gradients/gradients/roi_align_classifier_1/concat_grad/GatherV2_5:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("training_2/SGD/gradients/gradients/roi_align_classifier_1/concat_grad/Shape_1:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:435: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training_2/SGD/gradients/gradients/roi_align_classifier_1/concat_grad/sub_2:0", shape=(None,), dtype=int32), values=Tensor("training_2/SGD/gradients/gradients/roi_align_classifier_1/concat_grad/GatherV2_8:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("training_2/SGD/gradients/gradients/roi_align_classifier_1/concat_grad/Shape_2:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:435: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training_2/SGD/gradients/gradients/roi_align_classifier_1/concat_grad/sub_3:0", shape=(None,), dtype=int32), values=Tensor("training_2/SGD/gradients/gradients/roi_align_classifier_1/concat_grad/GatherV2_11:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("training_2/SGD/gradients/gradients/roi_align_classifier_1/concat_grad/Shape_3:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:435: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training_2/SGD/gradients/gradients/roi_align_mask_1/concat_grad/sub:0", shape=(None,), dtype=int32), values=Tensor("training_2/SGD/gradients/gradients/roi_align_mask_1/concat_grad/GatherV2_2:0", shape=(None, 14, 14, 256), dtype=float32), dense_shape=Tensor("training_2/SGD/gradients/gradients/roi_align_mask_1/concat_grad/Shape:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:435: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training_2/SGD/gradients/gradients/roi_align_mask_1/concat_grad/sub_1:0", shape=(None,), dtype=int32), values=Tensor("training_2/SGD/gradients/gradients/roi_align_mask_1/concat_grad/GatherV2_5:0", shape=(None, 14, 14, 256), dtype=float32), dense_shape=Tensor("training_2/SGD/gradients/gradients/roi_align_mask_1/concat_grad/Shape_1:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:435: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training_2/SGD/gradients/gradients/roi_align_mask_1/concat_grad/sub_2:0", shape=(None,), dtype=int32), values=Tensor("training_2/SGD/gradients/gradients/roi_align_mask_1/concat_grad/GatherV2_8:0", shape=(None, 14, 14, 256), dtype=float32), dense_shape=Tensor("training_2/SGD/gradients/gradients/roi_align_mask_1/concat_grad/Shape_2:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:435: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training_2/SGD/gradients/gradients/roi_align_mask_1/concat_grad/sub_3:0", shape=(None,), dtype=int32), values=Tensor("training_2/SGD/gradients/gradients/roi_align_mask_1/concat_grad/GatherV2_11:0", shape=(None, 14, 14, 256), dtype=float32), dense_shape=Tensor("training_2/SGD/gradients/gradients/roi_align_mask_1/concat_grad/Shape_3:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/tensorflow/python/framework/indexed_slices.py:435: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training_2/SGD/gradients/gradients/ROI_1/GatherV2_1_grad/Reshape_1:0", shape=(6000,), dtype=int32), values=Tensor("training_2/SGD/gradients/gradients/ROI_1/GatherV2_1_grad/Reshape:0", shape=(6000, 4), dtype=float32), dense_shape=Tensor("training_2/SGD/gradients/gradients/ROI_1/GatherV2_1_grad/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# 1/5 [=====>........................] - ETA: 4:00 - batch: 0.0000e+00 - size: 1.0000 - loss: 3.7233 - rpn_class_loss: 0.9178 - rpn_bbox_loss: 1.9386 - mrcnn_class_loss: 0.8670 - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00
# 2023-07-20 14:21:56.945224: I tensorflow/core/profiler/lib/profiler_session.cc:136] Profiler session initializing.
# 2023-07-20 14:21:56.945286: I tensorflow/core/profiler/lib/profiler_session.cc:155] Profiler session started.
# 2/5 [===========>..................] - ETA: 2:34 - batch: 0.5000 - size: 1.0000 - loss: 2.2607 - rpn_class_loss: 0.5436 - rpn_bbox_loss: 1.2270 - mrcnn_class_loss: 0.4901 - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00
# 2023-07-20 14:22:47.624510: I tensorflow/core/profiler/lib/profiler_session.cc:71] Profiler session collecting data.
# 2023-07-20 14:22:47.624804: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1487] CUPTI activity buffer flushed
# 2023-07-20 14:22:47.653530: I tensorflow/core/profiler/internal/gpu/cupti_collector.cc:228]  GpuTracer has collected 0 callback api events and 0 activity events.
# 2023-07-20 14:22:47.666938: I tensorflow/core/profiler/lib/profiler_session.cc:172] Profiler session tear down.
# 2023-07-20 14:22:47.701453: I tensorflow/core/profiler/rpc/client/save_profile.cc:137] Creating directory: /content/drive/MyDrive/test_work/logs/object20230720T1419/plugins/profile/2023_07_20_14_22_47
# 2023-07-20 14:22:47.720533: I tensorflow/core/profiler/rpc/client/save_profile.cc:143] Dumped gzipped tool data for trace.json.gz to /content/drive/MyDrive/test_work/logs/object20230720T1419/plugins/profile/2023_07_20_14_22_47/7ea35660606b.trace.json.gz
# 2023-07-20 14:22:47.746146: I tensorflow/core/profiler/rpc/client/save_profile.cc:137] Creating directory: /content/drive/MyDrive/test_work/logs/object20230720T1419/plugins/profile/2023_07_20_14_22_47
# 2023-07-20 14:22:47.749227: I tensorflow/core/profiler/rpc/client/save_profile.cc:143] Dumped gzipped tool data for memory_profile.json.gz to /content/drive/MyDrive/test_work/logs/object20230720T1419/plugins/profile/2023_07_20_14_22_47/7ea35660606b.memory_profile.json.gz
# 2023-07-20 14:22:47.770843: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: /content/drive/MyDrive/test_work/logs/object20230720T1419/plugins/profile/2023_07_20_14_22_47Dumped tool data for xplane.pb to /content/drive/MyDrive/test_work/logs/object20230720T1419/plugins/profile/2023_07_20_14_22_47/7ea35660606b.xplane.pb
# Dumped tool data for overview_page.pb to /content/drive/MyDrive/test_work/logs/object20230720T1419/plugins/profile/2023_07_20_14_22_47/7ea35660606b.overview_page.pb
# Dumped tool data for input_pipeline.pb to /content/drive/MyDrive/test_work/logs/object20230720T1419/plugins/profile/2023_07_20_14_22_47/7ea35660606b.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to /content/drive/MyDrive/test_work/logs/object20230720T1419/plugins/profile/2023_07_20_14_22_47/7ea35660606b.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to /content/drive/MyDrive/test_work/logs/object20230720T1419/plugins/profile/2023_07_20_14_22_47/7ea35660606b.kernel_stats.pb
# 5/5 [==============================] - ETA: 0s - batch: 2.0000 - size: 1.0000 - loss: 2.4879 - rpn_class_loss: 0.3062 - rpn_bbox_loss: 0.9494 - mrcnn_class_loss: 0.2489 - mrcnn_bbox_loss: 0.6218 - mrcnn_mask_loss: 0.3616
# /usr/local/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 5/5 [==============================] - 498s 110s/step - batch: 2.0000 - size: 1.0000 - loss: 2.4879 - rpn_class_loss: 0.3062 - rpn_bbox_loss: 0.9494 - mrcnn_class_loss: 0.2489 - mrcnn_bbox_loss: 0.6218 - mrcnn_mask_loss: 0.3616 - val_loss: 3.2926 - val_rpn_class_loss: 0.3354 - val_rpn_bbox_loss: 1.1606 - val_mrcnn_class_loss: 0.1112 - val_mrcnn_bbox_loss: 1.1266 - val_mrcnn_mask_loss: 0.5588
# Epoch 2/250
# 5/5 [==============================] - 448s 99s/step - batch: 2.0000 - size: 1.0000 - loss: 2.7312 - rpn_class_loss: 0.0926 - rpn_bbox_loss: 0.8276 - mrcnn_class_loss: 0.1822 - mrcnn_bbox_loss: 1.0887 - mrcnn_mask_loss: 0.5401 - val_loss: 1.9920 - val_rpn_class_loss: 0.1582 - val_rpn_bbox_loss: 0.5594 - val_mrcnn_class_loss: 0.0792 - val_mrcnn_bbox_loss: 0.6411 - val_mrcnn_mask_loss: 0.5542
# Epoch 3/250
# 5/5 [==============================] - 447s 98s/step - batch: 2.0000 - size: 1.0000 - loss: 1.9251 - rpn_class_loss: 0.0308 - rpn_bbox_loss: 0.5084 - mrcnn_class_loss: 0.0740 - mrcnn_bbox_loss: 0.7947 - mrcnn_mask_loss: 0.5172 - val_loss: 2.8865 - val_rpn_class_loss: 0.1836 - val_rpn_bbox_loss: 1.6765 - val_mrcnn_class_loss: 0.0294 - val_mrcnn_bbox_loss: 0.5542 - val_mrcnn_mask_loss: 0.4428
# Epoch 4/250
# 5/5 [==============================] - ETA: 0s - batch: 2.0000 - size: 1.0000 - loss: 2.0030 - rpn_class_loss: 0.0221 - rpn_bbox_loss: 0.5939 - mrcnn_class_loss: 0.1149 - mrcnn_bbox_loss: 0.7920 - mrcnn_mask_loss: 0.4801
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 14
#       8   utils.download_trained_weights(weights_path)
#      10 model.load_weights(weights_path, by_name=True, exclude=[
#      11             "mrcnn_class_logits", "mrcnn_bbox_fc",
#      12             "mrcnn_bbox", "mrcnn_mask"])
# ---> 14 train(model)
#
# Cell In[8], line 14, in train(model)
#      11 dataset_val.prepare()
#      13 # print("Training network heads")
# ---> 14 model.train(dataset_train, dataset_val,
#      15             learning_rate=config.LEARNING_RATE,
#      16             epochs=250,
#      17             layers='heads')
#
# File /content/mrcnn/model.py:2369, in MaskRCNN.train(self, train_dataset, val_dataset, learning_rate, epochs, layers, augmentation, custom_callbacks, no_augmentation_sources)
#    2366 else:
#    2367     workers = multiprocessing.cpu_count()
# -> 2369 self.keras_model.fit(
#    2370     train_generator,
#    2371     initial_epoch=self.epoch,
#    2372     epochs=epochs,
#    2373     steps_per_epoch=self.config.STEPS_PER_EPOCH,
#    2374     callbacks=callbacks,
#    2375     validation_data=val_generator,
#    2376     validation_steps=self.config.VALIDATION_STEPS,
#    2377     max_queue_size=100,
#    2378     workers=0,
#    2379     use_multiprocessing=False,
#    2380 )
#    2381 self.epoch = max(self.epoch, epochs)
#
# File /usr/local/lib/python3.8/site-packages/tensorflow/python/keras/engine/training_v1.py:789, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     786 self._check_call_args('fit')
#     788 func = self._select_training_loop(x)
# --> 789 return func.fit(
#     790     self,
#     791     x=x,
#     792     y=y,
#     793     batch_size=batch_size,
#     794     epochs=epochs,
#     795     verbose=verbose,
#     796     callbacks=callbacks,
#     797     validation_split=validation_split,
#     798     validation_data=validation_data,
#     799     shuffle=shuffle,
#     800     class_weight=class_weight,
#     801     sample_weight=sample_weight,
#     802     initial_epoch=initial_epoch,
#     803     steps_per_epoch=steps_per_epoch,
#     804     validation_steps=validation_steps,
#     805     validation_freq=validation_freq,
#     806     max_queue_size=max_queue_size,
#     807     workers=workers,
#     808     use_multiprocessing=use_multiprocessing)
#
# File /usr/local/lib/python3.8/site-packages/tensorflow/python/keras/engine/training_generator_v1.py:577, in GeneratorOrSequenceTrainingLoop.fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing)
#     574 model._validate_or_infer_batch_size(batch_size, steps_per_epoch, x)
#     575 training_utils_v1.check_generator_arguments(
#     576     y, sample_weight, validation_split=validation_split)
# --> 577 return fit_generator(
#     578     model,
#     579     x,
#     580     steps_per_epoch=steps_per_epoch,
#     581     epochs=epochs,
#     582     verbose=verbose,
#     583     callbacks=callbacks,
#     584     validation_data=validation_data,
#     585     validation_steps=validation_steps,
#     586     validation_freq=validation_freq,
#     587     class_weight=class_weight,
#     588     max_queue_size=max_queue_size,
#     589     workers=workers,
#     590     use_multiprocessing=use_multiprocessing,
#     591     shuffle=shuffle,
#     592     initial_epoch=initial_epoch,
#     593     steps_name='steps_per_epoch')
#
# File /usr/local/lib/python3.8/site-packages/tensorflow/python/keras/engine/training_generator_v1.py:301, in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     297 # Run the test loop every epoch during training.
#     298 if (do_validation and
#     299     training_utils_v1.should_run_validation(validation_freq, epoch) and
#     300     not callbacks.model.stop_training):
# --> 301   val_results = model_iteration(
#     302       model,
#     303       validation_data,
#     304       steps_per_epoch=validation_steps,
#     305       batch_size=batch_size,
#     306       class_weight=class_weight,
#     307       workers=workers,
#     308       use_multiprocessing=use_multiprocessing,
#     309       max_queue_size=max_queue_size,
#     310       callbacks=callbacks,
#     311       verbose=verbose,
#     312       mode=ModeKeys.TEST,
#     313       steps_name='validation_steps')
#     315   if not isinstance(val_results, list):
#     316     val_results = [val_results]
#
# File /usr/local/lib/python3.8/site-packages/tensorflow/python/keras/engine/training_generator_v1.py:219, in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     217 step = 0
#     218 while step < target_steps:
# --> 219   batch_data = _get_next_batch(generator)
#     220   if batch_data is None:
#     221     if is_dataset:
#     222       # The dataset passed by the user ran out of batches.
#     223       # Now we know the cardinality of the dataset.
#     224       # If steps_per_epoch was specified, then running out of data is
#     225       # unexpected, so we stop training and inform the user.
#
# File /usr/local/lib/python3.8/site-packages/tensorflow/python/keras/engine/training_generator_v1.py:353, in _get_next_batch(generator)
#     351 """Retrieves the next batch of input data."""
#     352 try:
# --> 353   generator_output = next(generator)
#     354 except (StopIteration, errors.OutOfRangeError):
#     355   return None
#
# File /usr/local/lib/python3.8/site-packages/tensorflow/python/keras/utils/data_utils.py:497, in iter_sequence_infinite(seq)
#     488 """Iterates indefinitely over a Sequence.
#     489
#     490 Arguments:
#    (...)
#     494   Batches of data from the `Sequence`.
#     495 """
#     496 while True:
# --> 497   for item in seq:
#     498     yield item
#
# File /usr/local/lib/python3.8/site-packages/tensorflow/python/keras/utils/data_utils.py:483, in Sequence.__iter__(self)
#     481 def __iter__(self):
#     482   """Create a generator that iterate over the Sequence."""
# --> 483   for item in (self[i] for i in range(len(self))):
#     484     yield item
#
# File /usr/local/lib/python3.8/site-packages/tensorflow/python/keras/utils/data_utils.py:483, in <genexpr>(.0)
#     481 def __iter__(self):
#     482   """Create a generator that iterate over the Sequence."""
# --> 483   for item in (self[i] for i in range(len(self))):
#     484     yield item
#
# File /content/mrcnn/model.py:1727, in DataGenerator.__getitem__(self, idx)
#    1724 # Get GT bounding boxes and masks for image.
#    1725 image_id = self.image_ids[image_index]
#    1726 image, image_meta, gt_class_ids, gt_boxes, gt_masks = \
# -> 1727     load_image_gt(self.dataset, self.config, image_id,
#    1728                   augmentation=self.augmentation)
#    1730 # Skip images that have no instances. This can happen in cases
#    1731 # where we train on a subset of classes and the image doesn't
#    1732 # have any of the classes we care about.
#    1733 if not np.any(gt_class_ids > 0):
#
# File /content/mrcnn/model.py:1241, in load_image_gt(dataset, config, image_id, augmentation)
#    1239 # Load image and mask
#    1240 image = dataset.load_image(image_id)
# -> 1241 mask, class_ids = dataset.load_mask(image_id)
#    1242 original_shape = image.shape
#    1243 image, window, scale, padding, crop = utils.resize_image(
#    1244     image,
#    1245     min_dim=config.IMAGE_MIN_DIM,
#    1246     min_scale=config.IMAGE_MIN_SCALE,
#    1247     max_dim=config.IMAGE_MAX_DIM,
#    1248     mode=config.IMAGE_RESIZE_MODE)
#
# Cell In[5], line 102, in CustomDataset.load_mask(self, image_id)
#      98 for i, p in enumerate(info["polygons"]):
#      99     # Get indexes of pixels inside the polygon and set them to 1
#     100 	rr, cc = skimage.draw.polygon(p['all_points_y'], p['all_points_x'])
# --> 102 	mask[rr, cc, i] = 1
#     104 # Return mask, and array of class IDs of each instance. Since we have
#     105 # one class ID only, we return an array of 1s
#     106 # Map class names to class IDs.
#     107 num_ids = np.array(num_ids, dtype=np.int32)
#
# IndexError: index 2160 is out of bounds for axis 0 with size 2160
